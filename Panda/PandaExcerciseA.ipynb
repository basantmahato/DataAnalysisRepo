# %%
import pandas as pd 
df = pd.read_csv("forbes.csv")
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
age_forbes = df['age']

# %%
age_forbes.mean()
# Out:
# np.float64(64.21068938807126)

# %%
age_forbes.shape
# Out:
# (2668,)

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# ...

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
df.tail()
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# ...

# %%
df1 = df[['personName','age','category']]

# %%
df1
# Out:
#                     personName   age               category
# 0                    Elon Musk  50.0             Automotive
# 1                   Jeff Bezos  58.0             Technology
# 2     Bernard Arnault & family  73.0       Fashion & Retail
# 3                   Bill Gates  66.0             Technology
# 4               Warren Buffett  91.0  Finance & Investments
# ...                        ...   ...                    ...
# 2663             Zhang Yuqiang  66.0          Manufacturing
# 2664                Zhou Ruxin  59.0             Technology
# 2665         Wen Zhou & family  57.0          Manufacturing
# 2666      Zhou Yifeng & family  43.0                 Energy
# 2667   Zhuang Kuilong & family  59.0          Manufacturing
#
# [2668 rows x 3 columns]

# %%
df.age
# Out:
# 0       50.0
# 1       58.0
# 2       73.0
# 3       66.0
# 4       91.0
#         ...
# 2663    66.0
# 2664    59.0
# 2665    57.0
# 2666    43.0
# 2667    59.0
# Name: age, Length: 2668, dtype: float64

# %%
df2=df.drop(columns=['finalWorth'])

# %%
df2
# Out:
#       rank                personName   age  year  month  \
# 0        1                 Elon Musk  50.0  2022      4
# 1        2                Jeff Bezos  58.0  2022      4
# 2        3  Bernard Arnault & family  73.0  2022      4
# 3        4                Bill Gates  66.0  2022      4
# 4        5            Warren Buffett  91.0  2022      4
# ...    ...                       ...   ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0  2022      4
# 2664  2578                Zhou Ruxin  59.0  2022      4
# 2665  2578         Wen Zhou & family  57.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# 1                Technology                   Amazon  United States
# 2          Fashion & Retail                     LVMH         France
# ...

# %%
df1.sort_values('age')
# Out:
#                personName   age               category
# 1311  Kevin David Lehmann  19.0       Fashion & Retail
# 2190   Alexandra Andresen  25.0            Diversified
# 2062          Wang Zelong  25.0        Metals & Mining
# 1975     Pedro Franceschi  25.0  Finance & Investments
# 1961    Henrique Dubugras  26.0  Finance & Investments
# ...                   ...   ...                    ...
# 2537        Shao Zengming   NaN          Manufacturing
# 2554        Wang Linxiang   NaN       Fashion & Retail
# 2556        Richard Warke   NaN        Metals & Mining
# 2572        Zeng Weixiong   NaN             Healthcare
# 2640     Stephan Schnabel   NaN          Manufacturing
#
# [2668 rows x 3 columns]

# %%
df3 = df1.sort_values('age', ascending=False)

# %%
df3
# Out:
#              personName    age               category
# 1681      George Joseph  100.0  Finance & Investments
# 1273     Charles Munger   98.0  Finance & Investments
# 1377      David Murdock   98.0        Food & Beverage
# 162         Robert Kuok   98.0            Diversified
# 1512  S. Daniel Abraham   97.0        Food & Beverage
# ...                 ...    ...                    ...
# 2537      Shao Zengming    NaN          Manufacturing
# 2554      Wang Linxiang    NaN       Fashion & Retail
# 2556      Richard Warke    NaN        Metals & Mining
# 2572      Zeng Weixiong    NaN             Healthcare
# 2640   Stephan Schnabel    NaN          Manufacturing
#
# [2668 rows x 3 columns]

# %%
df.loc[0:10]
# Out:
#     rank                personName   age  finalWorth  year  month  \
# 0      1                 Elon Musk  50.0    219000.0  2022      4
# 1      2                Jeff Bezos  58.0    171000.0  2022      4
# 2      3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3      4                Bill Gates  66.0    129000.0  2022      4
# 4      5            Warren Buffett  91.0    118000.0  2022      4
# 5      6                Larry Page  49.0    111000.0  2022      4
# 6      7               Sergey Brin  48.0    107000.0  2022      4
# 7      8             Larry Ellison  77.0    106000.0  2022      4
# 8      9             Steve Ballmer  66.0     91400.0  2022      4
# 9     10             Mukesh Ambani  64.0     90700.0  2022      4
# 10    11     Gautam Adani & family  59.0     90000.0  2022      4
#
#                  category                       source        country  \
# 0              Automotive                Tesla, SpaceX  United States
# ...

# %%
df.iat[0, 1]
# Out:
# 'Elon Musk'

# %%
df.isnull().count()
# Out:
# rank                    2668
# personName              2668
# age                     2668
# finalWorth              2668
# year                    2668
# month                   2668
# category                2668
# source                  2668
# country                 2668
# state                   2668
# city                    2668
# countryOfCitizenship    2668
# organization            2668
# selfMade                2668
# gender                  2668
# birthDate               2668
# title                   2668
# philanthropyScore       2668
# residenceMsa            2668
# numberOfSiblings        2668
# bio                     2668
# about                   2668
# dtype: int64

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.iloc[0:10, [1, 2, 5]]
# Out:
#                  personName   age  month
# 0                 Elon Musk  50.0      4
# 1                Jeff Bezos  58.0      4
# 2  Bernard Arnault & family  73.0      4
# 3                Bill Gates  66.0      4
# 4            Warren Buffett  91.0      4
# 5                Larry Page  49.0      4
# 6               Sergey Brin  48.0      4
# 7             Larry Ellison  77.0      4
# 8             Steve Ballmer  66.0      4
# 9             Mukesh Ambani  64.0      4

# %%
df.memory_usage()
# Out:
# Index                     132
# rank                    21344
# personName              21344
# age                     21344
# finalWorth              21344
# year                    21344
# month                   21344
# category                21344
# source                  21344
# country                 21344
# state                   21344
# city                    21344
# countryOfCitizenship    21344
# organization            21344
# selfMade                 2668
# gender                  21344
# birthDate               21344
# title                   21344
# philanthropyScore       21344
# residenceMsa            21344
# numberOfSiblings        21344
# bio                     21344
# about                   21344
# dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 59.0     82
# 57.0     82
# 58.0     81
# 54.0     78
# 60.0     76
#          ..
# 27.0      2
# 29.0      2
# 26.0      2
# 19.0      1
# 100.0     1
# Name: count, Length: 76, dtype: int64

# %%
df.nunique( dropna=False , axis = 0)
# Out:
# rank                     228
# personName              2666
# age                       77
# finalWorth               228
# year                       1
# month                      1
# category                  18
# source                   914
# country                   74
# state                     43
# city                     750
# countryOfCitizenship      75
# organization             317
# selfMade                   2
# gender                     3
# birthDate               2045
# title                     95
# philanthropyScore          6
# residenceMsa             110
# numberOfSiblings          11
# bio                     2668
# about                   1549
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
# ...

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# %%
dataframe =pd.DataFrame(data)

# %%
dataframe.isnull()
# Out:
#    calories  duration
# 0     False     False
# 1     False     False
# 2     False     False

# %%
df.isnull()
# Out:
#        rank  personName    age  finalWorth   year  month  category  source  \
# 0     False       False  False       False  False  False     False   False
# 1     False       False  False       False  False  False     False   False
# 2     False       False  False       False  False  False     False   False
# 3     False       False  False       False  False  False     False   False
# 4     False       False  False       False  False  False     False   False
# ...     ...         ...    ...         ...    ...    ...       ...     ...
# 2663  False       False  False       False  False  False     False   False
# 2664  False       False  False       False  False  False     False   False
# 2665  False       False  False       False  False  False     False   False
# 2666  False       False  False       False  False  False     False   False
# 2667  False       False  False       False  False  False     False   False
#
# ...

# %%
df.isnull().count()
# Out:
# rank                    2668
# personName              2668
# age                     2668
# finalWorth              2668
# year                    2668
# month                   2668
# category                2668
# source                  2668
# country                 2668
# state                   2668
# city                    2668
# countryOfCitizenship    2668
# organization            2668
# selfMade                2668
# gender                  2668
# birthDate               2668
# title                   2668
# philanthropyScore       2668
# residenceMsa            2668
# numberOfSiblings        2668
# bio                     2668
# about                   2668
# dtype: int64

# %%
df.notnull()
# Out:
#       rank  personName   age  finalWorth  year  month  category  source  \
# 0     True        True  True        True  True   True      True    True
# 1     True        True  True        True  True   True      True    True
# 2     True        True  True        True  True   True      True    True
# 3     True        True  True        True  True   True      True    True
# 4     True        True  True        True  True   True      True    True
# ...    ...         ...   ...         ...   ...    ...       ...     ...
# 2663  True        True  True        True  True   True      True    True
# 2664  True        True  True        True  True   True      True    True
# 2665  True        True  True        True  True   True      True    True
# 2666  True        True  True        True  True   True      True    True
# 2667  True        True  True        True  True   True      True    True
#
#       country  state  ...  organization  selfMade  gender  birthDate  title  \
# ...

# %%
dropped_df=df.dropna(axis = 1)

# %%
dropped_df.isnull()
# Out:
#        rank  personName  finalWorth   year  month  category  source  \
# 0     False       False       False  False  False     False   False
# 1     False       False       False  False  False     False   False
# 2     False       False       False  False  False     False   False
# 3     False       False       False  False  False     False   False
# 4     False       False       False  False  False     False   False
# ...     ...         ...         ...    ...    ...       ...     ...
# 2663  False       False       False  False  False     False   False
# 2664  False       False       False  False  False     False   False
# 2665  False       False       False  False  False     False   False
# 2666  False       False       False  False  False     False   False
# 2667  False       False       False  False  False     False   False
#
#       countryOfCitizenship  selfMade    bio
# 0                    False     False  False
# 1                    False     False  False
# ...

# %%
df.isnull()
# Out:
#        rank  personName    age  finalWorth   year  month  category  source  \
# 0     False       False  False       False  False  False     False   False
# 1     False       False  False       False  False  False     False   False
# 2     False       False  False       False  False  False     False   False
# 3     False       False  False       False  False  False     False   False
# 4     False       False  False       False  False  False     False   False
# ...     ...         ...    ...         ...    ...    ...       ...     ...
# 2663  False       False  False       False  False  False     False   False
# 2664  False       False  False       False  False  False     False   False
# 2665  False       False  False       False  False  False     False   False
# 2666  False       False  False       False  False  False     False   False
# 2667  False       False  False       False  False  False     False   False
#
# ...

# %%
filled_df=df.fillna(0)

# %%
filled_df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
filled_df.isnull()
# Out:
#        rank  personName    age  finalWorth   year  month  category  source  \
# 0     False       False  False       False  False  False     False   False
# 1     False       False  False       False  False  False     False   False
# 2     False       False  False       False  False  False     False   False
# 3     False       False  False       False  False  False     False   False
# 4     False       False  False       False  False  False     False   False
# ...     ...         ...    ...         ...    ...    ...       ...     ...
# 2663  False       False  False       False  False  False     False   False
# 2664  False       False  False       False  False  False     False   False
# 2665  False       False  False       False  False  False     False   False
# 2666  False       False  False       False  False  False     False   False
# 2667  False       False  False       False  False  False     False   False
#
# ...

# %%
filled_df.state[:50]
# Out:
# 0          Texas
# 1     Washington
# 2              0
# 3     Washington
# 4       Nebraska
# 5     California
# 6     California
# 7         Hawaii
# 8     Washington
# 9              0
# 10             0
# 11      New York
# 12             0
# 13             0
# 14    California
# 15      Arkansas
# 16             0
# 17         Texas
# 18      Arkansas
# 19             0
# 20        Kansas
# 21      New York
# 22             0
# 23         Texas
# 24             0
# 25             0
# 26        Oregon
# 27             0
# 28             0
# 29    Washington
# 30             0
# 31             0
# 32             0
# 33             0
# 34             0
# 35             0
# 36             0
# 37      New York
# 38             0
# 39             0
# 40      Virginia
# 41       Wyoming
# 42      New York
# 43      New York
# 44             0
# 45             0
# 46             0
# 47      New York
# 48             0
# 49        Nevada
# Name: state, dtype: object

# %%
df1.drop_duplicates().count()
# Out:
# personName    2668
# age           2582
# category      2668
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2663    False
# 2664    False
# 2665    False
# 2666    False
# 2667    False
# Length: 2668, dtype: bool

# %%
df1.transpose()
# Out:
#                   0           1                         2           3     \
# personName   Elon Musk  Jeff Bezos  Bernard Arnault & family  Bill Gates
# age               50.0        58.0                      73.0        66.0
# category    Automotive  Technology          Fashion & Retail  Technology
#
#                              4           5            6              7     \
# personName         Warren Buffett  Larry Page  Sergey Brin  Larry Ellison
# age                          91.0        49.0         48.0           77.0
# category    Finance & Investments  Technology   Technology     Technology
#
#                      8              9     ...            2658  \
# personName  Steve Ballmer  Mukesh Ambani  ...  Yao Hsiao Tung
# age                  66.0           64.0  ...            82.0
# category       Technology    Diversified  ...   Manufacturing
#
#                         2659         2660                    2661  \
# ...

# %%
df.rank()
# Out:
#         rank  personName     age  finalWorth    year   month  category  \
# 0        1.0       596.0   350.0      2668.0  1334.5  1334.5      35.5
# 1        2.0      1011.0   886.0      2667.0  1334.5  1334.5    2460.0
# 2        3.0       222.0  1892.5      2666.0  1334.5  1334.5     516.5
# 3        4.0       241.0  1429.5      2665.0  1334.5  1334.5    2460.0
# 4        5.0      2405.0  2527.5      2664.0  1334.5  1334.5     837.5
# ...      ...         ...     ...         ...     ...     ...       ...
# 2663  2623.0      2620.0  1429.5        46.0  1334.5  1334.5    1680.0
# 2664  2623.0      2654.0   967.5        46.0  1334.5  1334.5    2460.0
# 2665  2623.0      2422.0   804.5        46.0  1334.5  1334.5    1680.0
# 2666  2623.0      2655.0   150.5        46.0  1334.5  1334.5     344.0
# 2667  2623.0      2661.0   967.5        46.0  1334.5  1334.5    1680.0
#
#       source  country  state  ...  organization  selfMade  gender  birthDate  \
# ...

# %%
df.sort_values('age')
# Out:
#       rank           personName   age  finalWorth  year  month  \
# 1311  1292  Kevin David Lehmann  19.0      2400.0  2022      4
# 2190  2190   Alexandra Andresen  25.0      1300.0  2022      4
# 2062  1929          Wang Zelong  25.0      1500.0  2022      4
# 1975  1929     Pedro Franceschi  25.0      1500.0  2022      4
# 1961  1929    Henrique Dubugras  26.0      1500.0  2022      4
# ...    ...                  ...   ...         ...   ...    ...
# 2537  2448        Shao Zengming   NaN      1100.0  2022      4
# 2554  2448        Wang Linxiang   NaN      1100.0  2022      4
# 2556  2448        Richard Warke   NaN      1100.0  2022      4
# 2572  2448        Zeng Weixiong   NaN      1100.0  2022      4
# 2640  2578     Stephan Schnabel   NaN      1000.0  2022      4
#
#                    category       source        country       state  ...  \
# 1311       Fashion & Retail   drugstores            NaN         NaN  ...
# ...

# %%
df.sort_index()
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
df.set_index('rank')
# Out:
#                     personName   age  finalWorth  year  month  \
# rank
# 1                    Elon Musk  50.0    219000.0  2022      4
# 2                   Jeff Bezos  58.0    171000.0  2022      4
# 3     Bernard Arnault & family  73.0    158000.0  2022      4
# 4                   Bill Gates  66.0    129000.0  2022      4
# 5               Warren Buffett  91.0    118000.0  2022      4
# ...                        ...   ...         ...   ...    ...
# 2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# rank
# 1                Automotive            Tesla, SpaceX  United States
# 2                Technology                   Amazon  United States
# ...

# %%
df.sort_index(ascending = False)
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 0        1                 Elon Musk  50.0    219000.0  2022      4
#
#                    category                   source        country  \
# 2667          Manufacturing                polyester          China
# ...

# %%
df.reset_index()
# Out:
#       index  rank                personName   age  finalWorth  year  month  \
# 0         0     1                 Elon Musk  50.0    219000.0  2022      4
# 1         1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2         2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3         3     4                Bill Gates  66.0    129000.0  2022      4
# 4         4     5            Warren Buffett  91.0    118000.0  2022      4
# ...     ...   ...                       ...   ...         ...   ...    ...
# 2663   2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664   2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665   2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666   2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667   2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
# ...
