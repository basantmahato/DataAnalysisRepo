# %%
import pandas as pd 

weather = pd.read_csv("1. Weather Data.csv")
weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
weather.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
weather.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
weather.Weather.value_counts().unique()
# Out:
# array([2106, 2069, 1728, 1326,  390,  306,  188,  150,  116,   80,   60,
#          41,   37,   19,   18,   16,   15,   14,   11,    7,    6,    5,
#           4,    3,    2,    1])

# %%
weather.shape
# Out:
# (8784, 8)

# %%
weather.dropna()
weather.dropna(axis=1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
weather.rename(columns={'Weather ': 'Weather_Conditions'},inplace = False)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
weather[weather['Weather']=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
weather['Temp_C'].mean()
# Out:
# np.float64(8.798144353369764)

# %%
weather['Wind Speed_km/h'].mean()
# Out:
# np.float64(14.94546903460838)

# %%
weather['Visibility_km'].mean()
# Out:
# np.float64(27.664446721311478)

# %%
weather['Press_kPa'].var()
# Out:
# np.float64(0.7123440111838423)

# %%
windspeed=weather[(weather['Wind Speed_km/h']<=30)&(weather['Temp_C']>0)]

# %%
windspeed['Date/Time']
# Out:
# 13        1/1/2012 13:00
# 14        1/1/2012 14:00
# 15        1/1/2012 15:00
# 16        1/1/2012 16:00
# 17        1/1/2012 17:00
#               ...
# 8545     12/22/2012 1:00
# 8546     12/22/2012 2:00
# 8547     12/22/2012 3:00
# 8779    12/31/2012 19:00
# 8780    12/31/2012 20:00
# Name: Date/Time, Length: 6302, dtype: object

# %%
snow = weather[weather['Weather']=='Snow']
snow.loc[:,['Date/Time','Temp_C']]
# Out:
#              Date/Time  Temp_C
# 55       1/3/2012 7:00   -14.0
# 84      1/4/2012 12:00   -13.7
# 86      1/4/2012 14:00   -11.3
# 87      1/4/2012 15:00   -10.2
# 88      1/4/2012 16:00    -9.4
# ...                ...     ...
# 8779  12/31/2012 19:00     0.1
# 8780  12/31/2012 20:00     0.2
# 8781  12/31/2012 21:00    -0.5
# 8782  12/31/2012 22:00    -0.2
# 8783  12/31/2012 23:00     0.0
#
# [390 rows x 2 columns]

# %%
weather.Temp_C.plot(kind= "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
weather.Temp_C.value_counts().plot(kind= "bar")
