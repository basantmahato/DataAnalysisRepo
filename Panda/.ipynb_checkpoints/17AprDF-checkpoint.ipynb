# %%
import pandas as pd

df = pd.read_csv("forbes.csv")

# %%
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
df.head(10)
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
# 5     6                Larry Page  49.0    111000.0  2022      4
# 6     7               Sergey Brin  48.0    107000.0  2022      4
# 7     8             Larry Ellison  77.0    106000.0  2022      4
# 8     9             Steve Ballmer  66.0     91400.0  2022      4
# 9    10             Mukesh Ambani  64.0     90700.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# ...

# %%
df.tail()
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# ...

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
df.isnull().count()
# Out:
# rank                    2668
# personName              2668
# age                     2668
# finalWorth              2668
# year                    2668
# month                   2668
# category                2668
# source                  2668
# country                 2668
# state                   2668
# city                    2668
# countryOfCitizenship    2668
# organization            2668
# selfMade                2668
# gender                  2668
# birthDate               2668
# title                   2668
# philanthropyScore       2668
# residenceMsa            2668
# numberOfSiblings        2668
# bio                     2668
# about                   2668
# dtype: int64

# %%
na = df.dropna()

# %%
na
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 na
#
# NameError: name 'na' is not defined

# %%
df.dropna(axis=1)
# Out:
#       rank                personName  finalWorth  year  month  \
# 0        1                 Elon Musk    219000.0  2022      4
# 1        2                Jeff Bezos    171000.0  2022      4
# 2        3  Bernard Arnault & family    158000.0  2022      4
# 3        4                Bill Gates    129000.0  2022      4
# 4        5            Warren Buffett    118000.0  2022      4
# ...    ...                       ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang      1000.0  2022      4
# 2664  2578                Zhou Ruxin      1000.0  2022      4
# 2665  2578         Wen Zhou & family      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family      1000.0  2022      4
#
#                    category                   source countryOfCitizenship  \
# 0                Automotive            Tesla, SpaceX        United States
# ...

# %%
df.dtypes
# Out:
# rank                      int64
# personName               object
# age                     float64
# finalWorth              float64
# year                      int64
# month                     int64
# category                 object
# source                   object
# country                  object
# state                    object
# city                     object
# countryOfCitizenship     object
# organization             object
# selfMade                   bool
# gender                   object
# birthDate                object
# title                    object
# philanthropyScore       float64
# residenceMsa             object
# numberOfSiblings        float64
# bio                      object
# about                    object
# dtype: object

# %%
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
df2 = df.loc[:, ["rank", "personName", "age", "finalWorth", "category", "country", "gender"]]

# %%
df2
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0    219000.0             Automotive
# 1        2                Jeff Bezos  58.0    171000.0             Technology
# 2        3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3        4                Bill Gates  66.0    129000.0             Technology
# 4        5            Warren Buffett  91.0    118000.0  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0          Manufacturing
# 2664  2578                Zhou Ruxin  59.0      1000.0             Technology
# 2665  2578         Wen Zhou & family  57.0      1000.0          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0      1000.0                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0          Manufacturing
#
#             country gender
# ...

# %%
df3=df2.rename(columns={'rank': 'ID', 'personName': 'Name','age':'years','finalWorth':'Profit','category':'genre','country':'region','gender':'sex'}, inplace=True)

# %%
df3=df2.rename(columns={'rank': 'ID', 'personName': 'Name','age':'years','finalWorth':'Profit','category':'genre','country':'region','gender':'sex'}, inplace=True)
