# %%
import pandas as pd

csv = pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\CSV\\customers.csv")

print(csv)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c        NaN     Olsen
# 4       5  053d585Ab6b3159     Joanna       NaN
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv.dropna()
# Out:
#     Index      Customer Id First Name Last Name                       Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter               Rasmussen Group
# 2       3  6F94879bDAfE5a6        Roy     Berry                 Murillo-Perry
# 5       6  2d08FB17EE273F4      Aimee     Downs                  Steele Group
# 7       8  0e04AFde9f225dE      Brett    Mullen  Sanford, Davenport and Giles
# 8       9  C2dE4dEEc489ae0     Sheryl    Meyers                Browning-Simon
# ..    ...              ...        ...       ...                           ...
# 95     96  cb8E23e48d22Eae       Karl     Greer                     Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson         Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra                 Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer            Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes            Le, Nash and Cross
#
#                City
# ...

# %%
import pandas as pd

csv2 = pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\CSV\\customers.csv")

csv2.dropna(axis=1)
# Out:
#     Index
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
#
# [100 rows x 1 columns]

# %%
import pandas as pd

csv3 = pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\CSV\\customers.csv")

csv3.dropna(how="all")
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2     3.0  6F94879bDAfE5a6        Roy      Berry
# 3     4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4     5.0  053d585Ab6b3159     Joanna        NaN
# 5     6.0  2d08FB17EE273F4      Aimee      Downs
# 6     7.0  EA4d384DfDbBf77     Darren        NaN
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# 15   16.0  8cad0b4CBceaeec    Miranda    Beasley
# 16   17.0  a5DC21AE3a21eaA   Caroline      Foley
# 17   18.0  F8Aa9d6DfcBeeF8       Greg       Mata
# 18   19.0  F160f5Db3EfE973   Clifford   Jacobson
# ...

# %%
missing = csv3.loc[7]

# %%
missing
# Out:
# Index            8
# Customer Id    NaN
# First Name     NaN
# Last Name      NaN
# Company        NaN
# City           NaN
# Name: 7, dtype: object

# %%
csv3.iloc[7]
# Out:
# Index            8
# Customer Id    NaN
# First Name     NaN
# Last Name      NaN
# Company        NaN
# City           NaN
# Name: 7, dtype: object

# %%
import pandas as pd

csv4= pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\CSV\\customers.csv")

csv4
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2     3.0  6F94879bDAfE5a6        Roy      Berry
# 3     4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4     5.0  053d585Ab6b3159     Joanna        NaN
# 5     6.0  2d08FB17EE273F4      Aimee      Downs
# 6     7.0  EA4d384DfDbBf77     Darren        NaN
# 7     8.0              NaN        NaN        NaN
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# 15   16.0  8cad0b4CBceaeec    Miranda    Beasley
# 16   17.0  a5DC21AE3a21eaA   Caroline      Foley
# 17   18.0  F8Aa9d6DfcBeeF8       Greg       Mata
# ...

# %%
import pandas as pd

csv6= pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\CSV\\customers.csv")

csv6.dropna(how="all")
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2     3.0  6F94879bDAfE5a6        Roy      Berry
# 3     4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4     5.0  053d585Ab6b3159     Joanna        NaN
# 5     6.0  2d08FB17EE273F4      Aimee      Downs
# 6     7.0  EA4d384DfDbBf77     Darren        NaN
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# 15   16.0  8cad0b4CBceaeec    Miranda    Beasley
# 16   17.0  a5DC21AE3a21eaA   Caroline      Foley
# 17   18.0  F8Aa9d6DfcBeeF8       Greg       Mata
# 18   19.0  F160f5Db3EfE973   Clifford   Jacobson
# ...

# %%
csv6.to_csv("customersupdated.csv")

# %%
csv6
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2     3.0  6F94879bDAfE5a6        Roy      Berry
# 3     4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4     5.0  053d585Ab6b3159     Joanna        NaN
# 5     6.0  2d08FB17EE273F4      Aimee      Downs
# 6     7.0  EA4d384DfDbBf77     Darren        NaN
# 7     NaN              NaN        NaN        NaN
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# 15   16.0  8cad0b4CBceaeec    Miranda    Beasley
# 16   17.0  a5DC21AE3a21eaA   Caroline      Foley
# 17   18.0  F8Aa9d6DfcBeeF8       Greg       Mata
# ...

# %%
csv6.dropna()
# Out:
#     Index      Customer Id First Name  Last Name                     Company  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter             Rasmussen Group
# 2     3.0  6F94879bDAfE5a6        Roy      Berry               Murillo-Perry
# 5     6.0  2d08FB17EE273F4      Aimee      Downs                Steele Group
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers              Browning-Simon
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher                Beck-Hendrix
# 10   11.0  216E205d6eBb815       Carl  Schroeder  Oconnell, Meza and Everett
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson   Hoffman, Reed and Mcclain
# 12   13.0  e35426EbDEceaFF     Tracey       Mata              Graham-Francis
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox              Carpenter-Cook
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz              Carter-Hancock
# 15   16.0  8cad0b4CBceaeec    Miranda    Beasley          Singleton and Sons
# ...

# %%
import pandas as pd

csv7= pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\CSV\\customers.csv")

csv7.dropna(subset=["Company"])
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2     3.0  6F94879bDAfE5a6        Roy      Berry
# 3     4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 5     6.0  2d08FB17EE273F4      Aimee      Downs
# 6     7.0  EA4d384DfDbBf77     Darren        NaN
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# 15   16.0  8cad0b4CBceaeec    Miranda    Beasley
# 16   17.0  a5DC21AE3a21eaA   Caroline      Foley
# 17   18.0  F8Aa9d6DfcBeeF8       Greg       Mata
# 18   19.0  F160f5Db3EfE973   Clifford   Jacobson
# 19   20.0  0F60FF3DdCd7aB0     Joanna       Kirk
# ...

# %%
import pandas as pd

var = pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\customersupdated.csv")

# %%
var
# Out:
#     Unnamed: 0  Index      Customer Id First Name  Last Name  \
# 0            0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1    2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2            2    3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3    4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4            4    5.0  053d585Ab6b3159     Joanna        NaN
# 5            5    6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6    7.0  EA4d384DfDbBf77     Darren        NaN
# 7            7    NaN              NaN        NaN        NaN
# 8            8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9   10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10   11.0  216E205d6eBb815       Carl  Schroeder
# 11          11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12          12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13          13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# ...

# %%
var.dropna(subset=["Company"])
# Out:
#     Unnamed: 0  Index      Customer Id First Name  Last Name  \
# 0            0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1    2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2            2    3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3    4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4            4    5.0  053d585Ab6b3159     Joanna        NaN
# 5            5    6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6    7.0  EA4d384DfDbBf77     Darren        NaN
# 8            8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9   10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10   11.0  216E205d6eBb815       Carl  Schroeder
# 11          11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12          12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13          13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14          14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# ...

# %%
var.dropna(thresh=2)
# Out:
#     Unnamed: 0  Index      Customer Id First Name  Last Name  \
# 0            0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1    2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2            2    3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3    4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4            4    5.0  053d585Ab6b3159     Joanna        NaN
# 5            5    6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6    7.0  EA4d384DfDbBf77     Darren        NaN
# 8            8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9   10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10   11.0  216E205d6eBb815       Carl  Schroeder
# 11          11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12          12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13          13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14          14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# ...

# %%
import pandas as pd 

var2 = pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\customersupdated.csv")

# %%
var2
# Out:
#     Unnamed: 0  Index      Customer Id First Name  Last Name  \
# 0            0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1    2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2            2    3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3    4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4            4    5.0  053d585Ab6b3159     Joanna        NaN
# 5            5    6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6    7.0  EA4d384DfDbBf77     Darren        NaN
# 7            7    NaN              NaN        NaN        NaN
# 8            8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9   10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10   11.0  216E205d6eBb815       Carl  Schroeder
# 11          11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12          12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13          13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# ...

# %%
var2.fillna("python")
# Out:
#     Unnamed: 0   Index      Customer Id First Name  Last Name  \
# 0            0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1     2.0  1Ef7b82A4CAAD10    Preston     python
# 2            2     3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3     4.0  5Cef8BFA16c5e3c     python      Olsen
# 4            4     5.0  053d585Ab6b3159     Joanna     python
# 5            5     6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6     7.0  EA4d384DfDbBf77     Darren     python
# 7            7  python           python     python     python
# 8            8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10    11.0  216E205d6eBb815       Carl  Schroeder
# 11          11    12.0  CEDec94deE6d69B      Jenna     Dodson
# 12          12    13.0  e35426EbDEceaFF     Tracey       Mata
# 13          13    14.0  A08A8aF8BE9FaD4   Kristine        Cox
# ...

# %%
import pandas as pd 

var3 = pd.read_csv("C:\\Users\\BASANT\\Python\\Panda\\customersupdated.csv")

var3.fillna({"Company":"Khali"})
# Out:
#     Unnamed: 0  Index      Customer Id First Name  Last Name  \
# 0            0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1    2.0  1Ef7b82A4CAAD10    Preston        NaN
# 2            2    3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3    4.0  5Cef8BFA16c5e3c        NaN      Olsen
# 4            4    5.0  053d585Ab6b3159     Joanna        NaN
# 5            5    6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6    7.0  EA4d384DfDbBf77     Darren        NaN
# 7            7    NaN              NaN        NaN        NaN
# 8            8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9   10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10   11.0  216E205d6eBb815       Carl  Schroeder
# 11          11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12          12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13          13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# ...

# %%
var3.fillna(method="ffill")
# Out:
# C:\Users\BASANT\AppData\Local\Temp\ipykernel_31608\2665856796.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var3.fillna(method="ffill")
#     Unnamed: 0  Index      Customer Id First Name  Last Name  \
# 0            0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1            1    2.0  1Ef7b82A4CAAD10    Preston     Baxter
# 2            2    3.0  6F94879bDAfE5a6        Roy      Berry
# 3            3    4.0  5Cef8BFA16c5e3c        Roy      Olsen
# 4            4    5.0  053d585Ab6b3159     Joanna      Olsen
# 5            5    6.0  2d08FB17EE273F4      Aimee      Downs
# 6            6    7.0  EA4d384DfDbBf77     Darren      Downs
# 7            7    7.0  EA4d384DfDbBf77     Darren      Downs
# 8            8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9            9   10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10          10   11.0  216E205d6eBb815       Carl  Schroeder
# ...
