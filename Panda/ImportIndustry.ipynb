# %%
import pandas as pd
import random

df = pd.read_csv("industry.csv")
l = [random.randint(1, 100) for _ in range(43)]

df

df.insert(1,"Random",l)

# %%
df
# Out:
#                          Industry  Random
# 0              Accounting/Finance     100
# 1    Advertising/Public Relations      61
# 2              Aerospace/Aviation      64
# 3   Arts/Entertainment/Publishing      51
# 4                      Automotive      11
# 5                Banking/Mortgage       9
# 6            Business Development     100
# 7            Business Opportunity      15
# 8         Clerical/Administrative      96
# 9         Construction/Facilities      76
# 10                 Consumer Goods      73
# 11               Customer Service      12
# 12             Education/Training      36
# 13               Energy/Utilities      83
# 14                    Engineering      56
# 15            Government/Military      18
# 16                          Green      71
# 17                     Healthcare      60
# 18             Hospitality/Travel      37
# 19                Human Resources       6
# 20       Installation/Maintenance      96
# ...

# %%
df.to_csv("UpdatedIndustry.csv")
