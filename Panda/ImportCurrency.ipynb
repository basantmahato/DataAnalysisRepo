# %%
csv1 = pd.read_csv('C:\\Users\\BASANT\\Python\\Panda\\CSV\\currency.csv')

# %%
csv1
# Out:
#     Code Symbol                      Name
# 0    AED    د.إ    United Arab Emirates d
# 1    AFN      ؋            Afghan afghani
# 2    ALL      L              Albanian lek
# 3    AMD    AMD             Armenian dram
# 4    ANG      ƒ  Netherlands Antillean gu
# ..   ...    ...                       ...
# 158  XOF    CFA    West African CFA franc
# 159  XPF     Fr                 CFP franc
# 160  YER      ﷼               Yemeni rial
# 161  ZAR      R        South African rand
# 162  ZMW     ZK            Zambian kwacha
#
# [163 rows x 3 columns]

# %%
csv2.index.array
# Out:
# <NumpyExtensionArray>
# [  np.int64(0),   np.int64(1),   np.int64(2),   np.int64(3),   np.int64(4),
#    np.int64(5),   np.int64(6),   np.int64(7),   np.int64(8),   np.int64(9),
#  ...
#  np.int64(153), np.int64(154), np.int64(155), np.int64(156), np.int64(157),
#  np.int64(158), np.int64(159), np.int64(160), np.int64(161), np.int64(162)]
# Length: 163, dtype: int64

# %%
csv1.index.array
# Out:
# <NumpyExtensionArray>
# [  np.int64(0),   np.int64(1),   np.int64(2),   np.int64(3),   np.int64(4),
#    np.int64(5),   np.int64(6),   np.int64(7),   np.int64(8),   np.int64(9),
#  ...
#  np.int64(153), np.int64(154), np.int64(155), np.int64(156), np.int64(157),
#  np.int64(158), np.int64(159), np.int64(160), np.int64(161), np.int64(162)]
# Length: 163, dtype: int64

# %%
csv1.to_numpy()
# Out:
# array([['AED', 'د.إ', 'United Arab Emirates d'],
#        ['AFN', '؋', 'Afghan afghani'],
#        ['ALL', 'L', 'Albanian lek'],
#        ['AMD', 'AMD', 'Armenian dram'],
#        ['ANG', 'ƒ', 'Netherlands Antillean gu'],
#        ['AOA', 'Kz', 'Angolan kwanza'],
#        ['ARS', '$', 'Argentine peso'],
#        ['AUD', '$', 'Australian dollar'],
#        ['AWG', 'Afl.', 'Aruban florin'],
#        ['AZN', 'AZN', 'Azerbaijani manat'],
#        ['BAM', 'KM', 'Bosnia and Herzegovina '],
#        ['BBD', '$', 'Barbadian dollar'],
#        ['BDT', '৳ ', 'Bangladeshi taka'],
#        ['BGN', 'лв.', 'Bulgarian lev'],
#        ['BHD', '.د.ب', 'Bahraini dinar'],
#        ['BIF', 'Fr', 'Burundian franc'],
#        ['BMD', '$', 'Bermudian dollar'],
#        ['BND', '$', 'Brunei dollar'],
#        ['BOB', 'Bs.', 'Bolivian boliviano'],
#        ['BRL', 'R$', 'Brazilian real'],
#        ['BSD', '$', 'Bahamian dollar'],
#        ['BTC', '฿', 'Bitcoin'],
# ...

# %%
csv1.sort_index(axis=0,ascending=False)
# Out:
#     Code Symbol                      Name
# 162  ZMW     ZK            Zambian kwacha
# 161  ZAR      R        South African rand
# 160  YER      ﷼               Yemeni rial
# 159  XPF     Fr                 CFP franc
# 158  XOF    CFA    West African CFA franc
# ..   ...    ...                       ...
# 4    ANG      ƒ  Netherlands Antillean gu
# 3    AMD    AMD             Armenian dram
# 2    ALL      L              Albanian lek
# 1    AFN      ؋            Afghan afghani
# 0    AED    د.إ    United Arab Emirates d
#
# [163 rows x 3 columns]

# %%
csv1.loc[0,"Code"] ="Codes"
csv1
# Out:
#       Code Symbol                      Name
# 0    Codes    د.إ    United Arab Emirates d
# 1      AFN      ؋            Afghan afghani
# 2      ALL      L              Albanian lek
# 3      AMD    AMD             Armenian dram
# 4      ANG      ƒ  Netherlands Antillean gu
# ..     ...    ...                       ...
# 158    XOF    CFA    West African CFA franc
# 159    XPF     Fr                 CFP franc
# 160    YER      ﷼               Yemeni rial
# 161    ZAR      R        South African rand
# 162    ZMW     ZK            Zambian kwacha
#
# [163 rows x 3 columns]

# %%
csv1.loc[[2,3],["Code","Name"]]
# Out:
#   Code           Name
# 2  ALL   Albanian lek
# 3  AMD  Armenian dram

# %%
csv1.loc[:,["Code","Name"]]
# Out:
#       Code                      Name
# 0    Codes    United Arab Emirates d
# 1      AFN            Afghan afghani
# 2      ALL              Albanian lek
# 3      AMD             Armenian dram
# 4      ANG  Netherlands Antillean gu
# ..     ...                       ...
# 158    XOF    West African CFA franc
# 159    XPF                 CFP franc
# 160    YER               Yemeni rial
# 161    ZAR        South African rand
# 162    ZMW            Zambian kwacha
#
# [163 rows x 2 columns]

# %%
csv1.iloc[0,2] + csv1.iloc[1,2]
# Out:
# 'United Arab Emirates dAfghan afghani'
