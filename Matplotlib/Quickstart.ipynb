# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,4,6,8]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,4,6,8]

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,4,6,8]

c=["r",'g',"b",'y']

plt.bar(x,y,color=c)
plt.show()
